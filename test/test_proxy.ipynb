# %%
import requests
import random
import json 
import re
import os 
import base64
import time 
import glob 
import pandas as pd 
from bs4 import BeautifulSoup
import asyncio
from proxybroker import Broker
import multiprocessing
from collections import Counter
import datetime

# %%
def get_proxy_source1(config):
    url = 'https://www.sslproxies.org/'
    res = requests_get(url, config)
    if res:
        soup = BeautifulSoup(res['html'], 'html')
        table = soup.find('table', class_="table table-striped table-bordered")
        df = []
        if table is not None:
            cols = ['ip', 'port', 'code', 'country', 'level', 'google', 'https', 'last_checked']
            tbody = table.find('tbody')
            for tr in tbody.find_all('tr'):
                obj = dict(zip(cols, [td.text.strip() for td in tr.find_all('td')]))
                obj['level'] = obj['level'].split()[0]
                if obj['https'] == 'yes':
                    obj['https'] = True
                else:
                    obj['https'] = False
                df.append(obj)
        if df:
            df = pd.DataFrame(df)[['ip', 'port', 'country', 'level', 'https']]
            df['created'] = datetime.datetime.now().isoformat()[:10]
            return df


def get_proxy_source2(config):
    urls1 = [
        'http://free-proxy.cz/en/proxylist/country/all/http/ping/level1',
        'http://free-proxy.cz/en/proxylist/country/all/http/ping/level2',
        'http://free-proxy.cz/en/proxylist/country/all/https/ping/level1',
        'http://free-proxy.cz/en/proxylist/country/all/https/ping/level2',
    ]
    urls2 = [url+'/'+i for url in urls1 for i in '2345']
    df = []
    for url in urls1+urls2:
        res = requests_get(url, config)
        if res:
            soup = BeautifulSoup(res['html'], 'html')
            table = soup.find('table', {'id': 'proxy_list'})
            if table:
                cols = ['ip', 'port', 'https', 'country', 'region', 'city', 'level', 'speed', 'uptime', 'response', 'last_checked']
                tbody = table.find('tbody')
                for tr in tbody.find_all('tr'):
                    obj = dict(zip(cols, [td.text.strip() for td in tr.find_all('td')]))
                    if obj['level'] == 'High anonymity':
                        obj['level'] = 'elite'
                    else:
                        obj['level'] = 'anonymous'
                    if obj['https'] == 'HTTPS':
                        obj['https'] = True
                    else:
                        obj['https'] = False
                    df.append(obj)
    if df:
        df = pd.DataFrame(df)[['ip', 'port', 'country', 'level', 'https']]
        df['created'] = datetime.datetime.now().isoformat()[:10]
        return df


def get_proxy_source3(config):
    url = 'https://api.proxyscrape.com/v3/free-proxy-list/get?request=displayproxies&proxy_format=protocolipport&format=text'
    res = requests_get(url, config)
    if res:
        df = []
        for line in res['html'].split():
            if line.strip():
                obj = {'ip': line.split('//')[-1].split(':')[0],
                       'port': line.split('//')[-1].split(':')[1]}
                if line.split(':')[0] == 'http':
                    obj['https'] = False
                elif line.split(':')[0] == 'https':
                    obj['https'] = True
                else:
                    continue
                df.append(obj)
        df = pd.DataFrame(df)
        df['created'] = datetime.datetime.now().isoformat()[:10]
        return df


def requests_get(url, config=dict()):
    ntry = config.get('ntry', 1)
    verbose = config.get('verbose', False)
    for itry in range(ntry):
        if verbose:
            print(f'get({itry+1}/{ntry}):', url)
        if config.get('headers', None):
            if isinstance(config['headers'], str):
                headers = random.sample(json.load(open(config['headers'], 'r')), 1)[0]
                if verbose:
                    print('sampled one header from:', config['headers'])
            else:
                headers = config['headers']
        else:
            headers = None
        if config.get('proxies', None):
            if isinstance(config['proxies'], str):
                df = pd.read_csv(config['proxies'], dtype=str)
                for fkey, fvalue in config.get('proxies_filter', dict()).items():
                    if fkey in df.columns:
                        df = df[df[fkey].isin(fvalue)]
                if len(df) > 0:
                    irow = random.sample(list(df.index.values), 1)[0]
                    proxies = {
                        'http': 'http://'+df.loc[irow, 'ip']+':'+df.loc[irow, 'port'],
                        'https': 'https://'+df.loc[irow, 'ip']+':'+df.loc[irow, 'port'],
                    }
                    if verbose:
                        print('sampled one proxy from:', config['proxies'], '->', proxies)
                else:
                    print('No proxy meet the requirements:', config['proxies'])
                    proxies = None
            else:
                proxies = config['proxies']
        else:
            proxies = None
        try:
            t0 = time.time()
            res = requests.get(url,
                               headers=headers,
                               proxies=proxies,
                               timeout=config.get('timeout', 30), 
                               allow_redirects=config.get('allow_redirects', False),
                               verify=config.get('verify', True))
            latency = time.time()-t0
            if res.status_code == 200:
                if verbose:
                    print('Success in getting:', url, 'latency:', latency)
                return {'html': res.text, 'latency': latency}
            else:
                if verbose:
                    print(f'Abnormal status code ({res.status_code}) in getting({itry+1}/{ntry}):', url)
        except:
            if verbose:
                print(f'Failed in getting({itry+1}/{ntry}):', url)
        time.sleep(config.get('sleep', 0))


def update_proxies(sources=[get_proxy_source1, get_proxy_source3],
                   dir_source='/tmp', fsave=None, nprocess=32):
    url = 'http://www.aphanti.com/myip'
    config = {'verbose': True, 'ntry': 1, 'sleep': 0, 'timeout': 10,
              'verify': False, 'allow_redirects': False, 
              'headers': random.sample(json.load(open('../data/headers.json', 'r')), 1)[0],}    
    dfs = []
    for fn in glob.glob(dir_source+'/*.csv'):
        dfs.append(pd.read_csv(fn, dtype=str))

    for source in sources:
        df = source(config)
        fn = dir_source+'/'+source.__name__+'_'+datetime.datetime.now().isoformat()[:19]+'.csv'
        if df is not None:
            print(source.__name__, 'save', len(df), 'proxies to', fn)
            df.to_csv(fn, index=None)
            dfs.append(df)

    if dfs:
        df = pd.concat(dfs, axis=0, ignore_index=True)
        df = df.drop_duplicates(subset=['ip', 'port'])
        print('Total pool:', len(df))
        arglist = [(url, {**config, **{'proxies': {'http': 'http://'+df.loc[i, 'ip']+':'+df.loc[i, 'port'],
                                                   'https': 'https://'+df.loc[i, 'ip']+':'+df.loc[i, 'port']}}}) for i in df.index.values]
        with multiprocessing.Pool(processes=nprocess) as pool:
            results = pool.starmap(requests_get, arglist)
        df['latency'] = [x['latency'] if x else 1e9 for x in results]
        df['valid'] = [True if x else False for x in results]
        df['checked'] = datetime.datetime.now().isoformat()[:19]
    if fsave:
        os.makedirs(os.path.dirname(fsave), exist_ok=True)
        with open(fsave, 'w') as fid:
            df.to_csv(fsave, index=None)
    return df

# %%
update_proxies(sources=[get_proxy_source1, get_proxy_source3],
               dir_source='/home/alice/data/proxies/sources',
               fsave='/home/alice/data/proxies/checked.csv',
               nprocess=64)
# Out:
# get(1/1): https://www.sslproxies.org/
# /home/alice/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.sslproxies.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/alice/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.proxyscrape.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Success in getting: https://www.sslproxies.org/ latency: 0.2666819095611572
# get(1/1): https://api.proxyscrape.com/v3/free-proxy-list/get?request=displayproxies&proxy_format=protocolipport&format=text
# Success in getting: https://api.proxyscrape.com/v3/free-proxy-list/get?request=displayproxies&proxy_format=protocolipport&format=text latency: 0.3121070861816406
# get_proxy_source3 save 1004 proxies to /home/alice/data/proxies/sources/get_proxy_source3_2024-07-26T15:36:17.csv
# Total pool: 2074
# get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1): get(1/1):get(1/1):get(1/1): get(1/1): get(1/1):get(1/1):get(1/1):   get(1/1):get(1/1): get(1/1): get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1): get(1/1):get(1/1):   get(1/1):  http://www.aphanti.com/myip  get(1/1):get(1/1): get(1/1):get(1/1):http://www.aphanti.com/myipget(1/1):  get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1): http://www.aphanti.com/myip  http://www.aphanti.com/myiphttp://www.aphanti.com/myip http://www.aphanti.com/myipget(1/1):http://www.aphanti.com/myip get(1/1):http://www.aphanti.com/myip     get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):get(1/1):http://www.aphanti.com/myipget(1/1): get(1/1):  get(1/1):get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip http://www.aphanti.com/myiphttp://www.aphanti.com/myip
# http://www.aphanti.com/myip  http://www.aphanti.com/myip
# http://www.aphanti.com/myiphttp://www.aphanti.com/myip       http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# http://www.aphanti.com/myip
#   http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
# http://www.aphanti.com/myip
# http://www.aphanti.com/myip  http://www.aphanti.com/myip
#  http://www.aphanti.com/myip http://www.aphanti.com/myiphttp://www.aphanti.com/myip http://www.aphanti.com/myip http://www.aphanti.com/myip
#
# http://www.aphanti.com/myip
#
#
#
#
# http://www.aphanti.com/myip
#
# http://www.aphanti.com/myiphttp://www.aphanti.com/myip
# http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
# http://www.aphanti.com/myip
# http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
# http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
#
# http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
# http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
#
#
# http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# http://www.aphanti.com/myip
#
#
# http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
#
#
#
#
#
#
#
#
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.046135663986206055
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.10696816444396973
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.13814282417297363Abnormal status code (307) in getting(1/1):
# http://www.aphanti.com/myipget(1/1):
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.1682295799255371
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.1908280849456787
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.2230820655822754
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (500) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.10529541969299316
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3717801570892334
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4161078929901123
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (503) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4540975093841553
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Success in getting:  http://www.aphanti.com/myip
# http://www.aphanti.com/myip get(1/1):latency:  http://www.aphanti.com/myip0.4624974727630615
#
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.5394818782806396
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.37438106536865234
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.7469990253448486
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8210976123809814
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8461363315582275
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.849034309387207
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myipSuccess in getting:  http://www.aphanti.com/myiplatency:  0.30519533157348633latency:
# 0.8765037059783936
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Success in getting: http://www.aphanti.com/myip latency: 0.8857362270355225
# Abnormal status code (404) in getting(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): Success in getting: http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#  latency: 0.9031481742858887
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (403) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.46977996826171875
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9454617500305176
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip Success in getting:latency:  Abnormal status code (307) in getting(1/1):http://www.aphanti.com/myip0.957535982131958
#  latency:get(1/1): http://www.aphanti.com/myip 0.8504600524902344
# http://www.aphanti.com/myip
# get(1/1):
# get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Success in getting: http://www.aphanti.com/myip latency: 1.0642812252044678
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.102416753768921
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3422267436981201
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.2616748809814453
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.2795202732086182
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.4300096035003662
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.5517590045928955
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.3605034351348877
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.42253541946411133Failed in getting(1/1):
#  http://www.aphanti.com/myipget(1/1):
# http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.0694808959960938
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8947312831878662
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4273512363433838
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.962670087814331
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.0521304607391357
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.882681131362915
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3001384735107422
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting:Success in getting: http://www.aphanti.com/myip  http://www.aphanti.com/myiplatency:  latency: 0.109736680984497070.486400842666626
#
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Success in getting: http://www.aphanti.com/myip latency: 1.6302144527435303
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8876686096191406
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.670884609222412
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.273488759994507
# get(1/1):Success in getting:  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
# Success in getting:  latency:http://www.aphanti.com/myip  0.8391029834747314latency:
#  2.7646381855010986get(1/1):
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myipSuccess in getting:
#  get(1/1):Success in getting:http://www.aphanti.com/myip   http://www.aphanti.com/myiphttp://www.aphanti.com/myiplatency:
#   latency:2.3309555053710938
#  get(1/1):1.0400776863098145
# http://www.aphanti.com/myipget(1/1):
# http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9515218734741211
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.5687499046325684
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.486452341079712
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.5085484981536865
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.7754392623901367
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.848841428756714
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.2948031425476074
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9798688888549805
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 4.380398988723755
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.510601758956909
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4081990718841553
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.55816650390625
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (503) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): Failed in getting(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.35158371925354
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.1652045249938965
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.2982263565063477
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3630094528198242
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (407) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.0172860622406006
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.5774388313293457
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (307) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): Success in getting:http://www.aphanti.com/myip
# http://www.aphanti.com/myip latency: 0.09038114547729492
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.029648303985596
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.07738184928894
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8979306221008301
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.227172374725342
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.4359195232391357
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4876370429992676
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.0877540111541748
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.796672582626343
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.1989057064056396
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.4527034759521484
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8923087120056152
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 4.941544532775879
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (503) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.3787789344787598
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.876845121383667
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 7.183472633361816
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.9248411655426025
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 8.566322326660156
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.44112253189086914
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.42789387702941895
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.965151309967041
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3885228633880615
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.553037166595459
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.5300047397613525
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (503) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip Failed in getting(1/1):latency:  http://www.aphanti.com/myip0.4573850631713867
#
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Failed in getting(1/1): Failed in getting(1/1):Failed in getting(1/1):http://www.aphanti.com/myipFailed in getting(1/1):  Failed in getting(1/1):Failed in getting(1/1):Failed in getting(1/1): Failed in getting(1/1):Failed in getting(1/1):http://www.aphanti.com/myipFailed in getting(1/1):http://www.aphanti.com/myip
# Failed in getting(1/1):  Failed in getting(1/1):http://www.aphanti.com/myip
#    get(1/1): http://www.aphanti.com/myiphttp://www.aphanti.com/myip get(1/1):
# http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip http://www.aphanti.com/myip
# http://www.aphanti.com/myip
#
#  get(1/1):Failed in getting(1/1):
# Failed in getting(1/1):
# http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1):
# Failed in getting(1/1):get(1/1):get(1/1):http://www.aphanti.com/myip
#
#  get(1/1):get(1/1): get(1/1):
# get(1/1):   get(1/1):
#  http://www.aphanti.com/myipget(1/1):get(1/1):   http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip http://www.aphanti.com/myip http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
#  http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
#
# http://www.aphanti.com/myip
#
# http://www.aphanti.com/myip
#
# http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1):
# get(1/1):get(1/1):
# get(1/1):get(1/1):
#
#
#   http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
# http://www.aphanti.com/myip
# http://www.aphanti.com/myip
#
#
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.03929305076599121
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Abnormal status code (307) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1):Success in getting:  http://www.aphanti.com/myip
# http://www.aphanti.com/myip latency: 0.39589428901672363
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.8228743076324463
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.1717374324798584
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 10.672812700271606
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (302) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.33684253692626953
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9237756729125977
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Success in getting: Success in getting:http://www.aphanti.com/myip  http://www.aphanti.com/myiplatency:  0.037346601486206055latency:
#  0.9459960460662842get(1/1):
#  get(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9743003845214844
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):get(1/1): Success in getting:http://www.aphanti.com/myip  http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# get(1/1):  http://www.aphanti.com/myiplatency:
#  0.42368555068969727
# get(1/1): http://www.aphanti.com/myip
# Success in getting: Failed in getting(1/1):http://www.aphanti.com/myip  http://www.aphanti.com/myiplatency:
#  get(1/1):1.1340360641479492
# http://www.aphanti.com/myipget(1/1):
#  Failed in getting(1/1):http://www.aphanti.com/myip
#  http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.2412166595458984
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (504) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.557692050933838
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9055366516113281
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myipSuccess in getting:
#  get(1/1):http://www.aphanti.com/myip Failed in getting(1/1): http://www.aphanti.com/myip
# latency:http://www.aphanti.com/myip
# 0.862464189529419get(1/1):
#  get(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.895897388458252
# get(1/1): http://www.aphanti.com/myip
# Success in getting: Success in getting:http://www.aphanti.com/myip  http://www.aphanti.com/myiplatency:Success in getting:   latency:http://www.aphanti.com/myip 0.3798828125
# latency:2.045367479324341
# get(1/1):2.453777551651001
# get(1/1):http://www.aphanti.com/myipget(1/1):
#   http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Success in getting: http://www.aphanti.com/myip latency: Failed in getting(1/1):1.4079902172088623
# http://www.aphanti.com/myipget(1/1):
#  get(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myipFailed in getting(1/1):
#  http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9964373111724854
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.41884684562683105
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): Failed in getting(1/1):http://www.aphanti.com/myip http://www.aphanti.com/myip
#
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Success in getting: http://www.aphanti.com/myip latency: 0.1698758602142334
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (307) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.6710379123687744
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3565187454223633
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9995968341827393
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.341796875
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 7.38032603263855
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.1093759536743164
# get(1/1): http://www.aphanti.com/myip
# Success in getting:Success in getting:  http://www.aphanti.com/myiphttp://www.aphanti.com/myip  latency:latency:  3.161940097808838
# 1.2928235530853271get(1/1):
#  http://www.aphanti.com/myipget(1/1):
# http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.941727876663208
# Success in getting:get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
# latency: 0.3417963981628418
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myipSuccess in getting:
#  http://www.aphanti.com/myip latency: 0.38983726501464844
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.13622379302978516
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (503) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.5561881065368652
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (400) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting:Success in getting:  http://www.aphanti.com/myiphttp://www.aphanti.com/myip  latency: latency:2.647670030593872
# 2.2023727893829346get(1/1):
#  http://www.aphanti.com/myipget(1/1):
# http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3560960292816162
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.973930835723877
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.260068416595459
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.553220272064209
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.46415233612060547
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.21955204010009766
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.205389022827148
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.9654181003570557
# get(1/1): Success in getting:http://www.aphanti.com/myip
#  Abnormal status code (504) in getting(1/1):http://www.aphanti.com/myip  http://www.aphanti.com/myiplatency:
#  get(1/1):6.826937198638916
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Success in getting: Success in getting:http://www.aphanti.com/myip  http://www.aphanti.com/myiplatency: latency:  0.38259243965148926
# 5.849407911300659
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Success in getting:  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#  get(1/1):latency:  0.4176445007324219http://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.09228062629699707
# get(1/1): Success in getting:http://www.aphanti.com/myip
# http://www.aphanti.com/myip latency: 5.713268280029297
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.8822407722473145
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 4.079279184341431
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.11511898040771484
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): Failed in getting(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9054195880889893
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 14.868959903717041
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myipAbnormal status code (307) in getting(1/1):  latency:http://www.aphanti.com/myip
#  get(1/1):5.228796005249023
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.5574119091033936
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9290530681610107
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.03854012489318848
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.431030511856079
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.5440163612365723
# get(1/1):Success in getting:  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#  latency: 1.177659273147583
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.5822186470031738
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9157342910766602
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.9433486461639404
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9385519027709961
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.426771879196167
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 9.95242691040039
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.19018769264221191
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.4316370487213135
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Success in getting:  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#  get(1/1):latency:  http://www.aphanti.com/myip7.385040283203125
#
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 7.037780046463013
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 7.163940668106079
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.0655295848846436
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8313138484954834
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.8598880767822266
# get(1/1):Success in getting:  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#  latency: 2.9942357540130615
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.7941391468048096
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (403) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.07320785522460938
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 9.546358823776245
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 7.453360319137573
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1):Failed in getting(1/1):Failed in getting(1/1):    http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
#
# get(1/1):get(1/1):
# get(1/1):  get(1/1): http://www.aphanti.com/myiphttp://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# http://www.aphanti.com/myip
#
# Success in getting: http://www.aphanti.com/myip latency: 0.8789894580841064
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.2900526523590088
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.15891265869140625
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (400) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.36022281646728516
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8760890960693359
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 7.189732313156128
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.322983503341675
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.168851613998413
# get(1/1): http://www.aphanti.com/myip
# Success in getting: Failed in getting(1/1):http://www.aphanti.com/myipSuccess in getting:   http://www.aphanti.com/myiplatency:http://www.aphanti.com/myip
#   4.998750686645508get(1/1):latency:
#   get(1/1):http://www.aphanti.com/myip0.9209597110748291
#
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.09567022323608398
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (307) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.3606526851654053
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (302) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.190923690795898
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.5539028644561768
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myipSuccess in getting:
#  get(1/1):http://www.aphanti.com/myip  http://www.aphanti.com/myiplatency:
#  1.0503315925598145
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.6062703132629395
# get(1/1): http://www.aphanti.com/myip
# Success in getting: Abnormal status code (307) in getting(1/1):http://www.aphanti.com/myip  Failed in getting(1/1):http://www.aphanti.com/myiplatency:
#   get(1/1):http://www.aphanti.com/myip0.5633234977722168
#
# http://www.aphanti.com/myipget(1/1):get(1/1):
#   http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Success in getting: http://www.aphanti.com/myip latency: 7.891803979873657
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.175845146179199
# Failed in getting(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1):Failed in getting(1/1):  http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.2241785526275635
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.47721052169799805
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.4496517181396484
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9492182731628418
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.463616371154785
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myipSuccess in getting:  latency:http://www.aphanti.com/myip 10.333175897598267 latency:
#  get(1/1):5.109270095825195
#  http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3622910976409912
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.19688963890075684
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 4.38761568069458
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 8.38062834739685
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.4376087188720703
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 7.592599630355835
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 8.517903089523315
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): get(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 8.793820858001709
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9333486557006836
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.191603422164917
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 8.733304738998413
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.7280349731445312
# get(1/1): Failed in getting(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.0783882141113281
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4742436408996582
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.0933196544647217
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 4.403456211090088
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.286419630050659
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 8.777417659759521
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): Failed in getting(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):
# http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4319589138031006
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4981083869934082
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Abnormal status code (404) in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.8617663383483887
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9741673469543457
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3412184715270996
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.0896637439727783
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.29385828971862793
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (307) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 8.105953931808472
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): Success in getting:http://www.aphanti.com/myip
# http://www.aphanti.com/myip latency: 1.6077680587768555
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.4933807849884033
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.2578725814819336
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.887625217437744
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3889882564544678
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.0407013893127441
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (502) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (307) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.9938945770263672
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myipSuccess in getting:
#
#  get(1/1):http://www.aphanti.com/myip  http://www.aphanti.com/myiplatency:
#  3.772143602371216
# get(1/1): http://www.aphanti.com/myip
# ...
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.406266450881958
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Abnormal status code (504) in getting(1/1): Success in getting:http://www.aphanti.com/myip
# http://www.aphanti.com/myip get(1/1):latency:  0.3503735065460205http://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.4107201099395752
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): Success in getting:http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):  latency:http://www.aphanti.com/myip
# 6.209718704223633
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1):Abnormal status code (503) in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myipAbnormal status code (307) in getting(1/1):  http://www.aphanti.com/myiplatency:
#  get(1/1):5.237236738204956
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.0574102401733398
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 4.509761333465576
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.148335218429565
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.855400562286377
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myipFailed in getting(1/1):
#  get(1/1):http://www.aphanti.com/myip
# get(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.46201515197753906
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (307) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.7704603672027588
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 3.241955280303955
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 4.861735820770264
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Success in getting:  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#  get(1/1):latency:  http://www.aphanti.com/myip1.0773875713348389
#
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (307) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1):get(1/1):  Success in getting:http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# http://www.aphanti.com/myip latency: 0.34650158882141113
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.05577588081359863
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.33170151710510254
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myipFailed in getting(1/1):
#  get(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myipFailed in getting(1/1):
# get(1/1): http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1): http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):
#  get(1/1):Success in getting:http://www.aphanti.com/myip
# http://www.aphanti.com/myiphttp://www.aphanti.com/myip
# latency: 16.020620107650757
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.10237288475036621
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.202168941497803
# get(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
# get(1/1):
#  http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.239567041397095
# get(1/1): http://www.aphanti.com/myip
# Success in getting:Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
# get(1/1):latency:  http://www.aphanti.com/myip1.6871683597564697
#
# get(1/1): http://www.aphanti.com/myip
# Success in getting:Failed in getting(1/1):  http://www.aphanti.com/myip http://www.aphanti.com/myip
# latency:get(1/1):  1.0534358024597168http://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.3421709537506104
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): Abnormal status code (407) in getting(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):
# get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 15.498379230499268
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1):Failed in getting(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.09412240982055664
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.0365970134735107
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.408381700515747
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.3115730285644531
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.8570656776428223
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 2.161465644836426
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (404) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.443375587463379
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.4920110702514648
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: Failed in getting(1/1):0.5563910007476807
# http://www.aphanti.com/myipget(1/1):
#  get(1/1):http://www.aphanti.com/myipFailed in getting(1/1):
#  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 1.3023197650909424
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (409) in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.5666477680206299
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 5.9178149700164795
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1):Failed in getting(1/1): http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):
#  get(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency:Abnormal status code (307) in getting(1/1):  8.71746826171875http://www.aphanti.com/myip
#
# get(1/1):get(1/1):  http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# Failed in getting(1/1): http://www.aphanti.com/myipFailed in getting(1/1):
#  http://www.aphanti.com/myipget(1/1):
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 6.719160318374634Failed in getting(1/1):
#  get(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):
#  http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): Failed in getting(1/1): http://www.aphanti.com/myiphttp://www.aphanti.com/myip
#
# get(1/1): http://www.aphanti.com/myip
# Abnormal status code (503) in getting(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): get(1/1):Failed in getting(1/1):http://www.aphanti.com/myip
# http://www.aphanti.com/myipget(1/1):http://www.aphanti.com/myip
#  get(1/1):
# http://www.aphanti.com/myip
# http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 10.215615272521973
# get(1/1): http://www.aphanti.com/myip
# Failed in getting(1/1): http://www.aphanti.com/myip
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 7.965164422988892
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency:

# %%
# url = 'http://free-proxy.cz/en/proxylist/country/all/https/ping/level2'
# url = 'https://proxylist.geonode.com/api/proxy-list?limit=500&page=1&sort_by=lastChecked&sort_type=desc'
# url = 'https://api.proxyscrape.com/v3/free-proxy-list/get?request=displayproxies&proxy_format=protocolipport&format=text'
url = 'http://www.aphanti.com/myip'
config = {'verbose': True, 'ntry': 1, 'sleep': 0, 'timeout': 10,
          'verify': False, 'allow_redirects': False,
          'headers': random.sample(json.load(open('../data/headers.json', 'r')), 1)[0],
          'proxies': {'http': 'http://160.86.242.23:8080', 'https': 'https://160.86.242.23:8080'}
          # 'proxies': '~/data/proxies/pool.csv',
          # 'proxies_filter': {'valid': ['True']},
         }
res = requests_get(url, config)
res['html']
# Out:
# get(1/1): http://www.aphanti.com/myip
# Success in getting: http://www.aphanti.com/myip latency: 0.8135342597961426
# '{"REMOTE_ADDR": "160.86.242.23", "REMOTE_PORT": "17612", "REQUEST_METHOD": "GET", "REQUEST_SCHEME": "http", "REQUEST_URI": "/myip", "HTTP_USER_AGENT": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0", "datetime": "2024-07-24T13:52:39.159843", "city": "Osaka", "continent_code": "AS", "continent_name": "Asia", "country_code": "JP", "country_name": "Japan", "dma_code": null, "is_in_european_union": false, "latitude": 34.6833, "longitude": 135.5, "postal_code": "550-0001", "region": "27", "time_zone": "Asia/Tokyo"}'

# %%
df = pd.read_csv('/home/alice/data/proxies/checked.csv')
df.shape
# Out:
# <html><head><title>筷数云办公-登录</title></head><body></body></html>

# %%
df

# %%
isinstance('df', str)
# Out:
# True
